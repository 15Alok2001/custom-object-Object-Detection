# %%
# %cd /content/drive/MyDrive/NUT_BOLT/yolov5
# Out:
# /content/drive/MyDrive/NUT_BOLT/yolov5

# %%
# !pip install -r requirements.txt  # install

# %%
# !python detect.py --weights /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt --source dataset/test/t3.jpeg
# Out:
# detect: weights=['/content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt'], source=dataset/test/t3.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "gitpython>=3.1.30" not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per /content/drive/MyDrive/NUT_BOLT/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt --include pb
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['pb']
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt with output shape (1, 25200, 8) (54.2 MB)
# 2023-04-08 20:00:34.410182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ...

# %%
# import tensorflow as tf
# from tensorflow.python.saved_model import tag_constants

# %%
# # Load Nutbolt Model
# saved_model_loaded = tf.saved_model.load('/content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best_saved_model', tags=[tag_constants.SERVING])
# infer = saved_model_loaded.signatures['serving_default']

# %%
# import cv2, numpy as np

# input_size = 640
# img = cv2.imread('dataset/test/t3.jpeg')
# img = cv2.resize(img, (input_size, input_size))
# img = img / 255.
# img_data = np.asarray(img).astype(np.float32)

# %%
# batch_data = tf.constant(img_data)

# %%
# pred_bbox = infer(batch_data)

# %%
# for key, value in pred_bbox.items():
#     boxes = value[:, :, 0:4]
#     pred_conf = value[:, :, 4:]

# %%
# boxes, scores, classes, valid_detections = tf.image.combined_non_max_suppression(
#       boxes=tf.reshape(boxes, (tf.shape(boxes)[0], -1, 1, 4)),
#       scores=tf.reshape(
#           pred_conf, (tf.shape(pred_conf)[0], -1, tf.shape(pred_conf)[-1])),
#       max_output_size_per_class=50,
#       max_total_size=10,
#       iou_threshold=0.45,
#       score_threshold=0.30
# )

# %%
# def format_boxes(bboxes, image_height, image_width):
#     for box in bboxes:
#         ymin = int(box[0] * image_height)
#         xmin = int(box[1] * image_width)
#         ymax = int(box[2] * image_height)
#         xmax = int(box[3] * image_width)
#         box[0], box[1], box[2], box[3] = xmin, ymin, xmax, ymax

# %%
# img_data = cv2.imread('dataset/test/t3.jpeg')
# original_h, original_w, channel = img_data.shape

# %%
# original_h, original_w, channel

# %%
# boxes.numpy()[0]

# %%
# for box in boxes:
#       ymin = int(box[0] * original_h)
#       xmin = int(box[1] * original_w)
#       ymax = int(box[2] * original_h)
#       xmax = int(box[3] * original_w)
#       box[0], box[1], box[2], box[3] = xmin, ymin, xmax, ymax

#       print(xmin, ymin, xmax, ymax)

# %%
# bboxes = format_boxes(boxes.numpy()[0], original_h, original_w)

# %%
# pred_bbox = [bboxes, scores.numpy()[0], classes.numpy()[0], valid_detections.numpy()[0]]

# %%
# model = torch.load('yolov5s.pt')
import torch
model = torch.hub.load('.', 'custom', path='/content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/best.pt', source='local')
# Out:
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# Adding AutoShape...

# %%
import cv2
img_path = '/content/drive/MyDrive/NUT_BOLT/yolov5/dataset/test/t1.jpeg'
img = cv2.imread(img_path)

# %%
result = model(img)

# %%
result.pandas().xyxy[0]
# Out:
#            xmin         ymin         xmax         ymax  confidence  class  \
# 0    671.602173   682.818848   721.774292   721.849609    0.857980      2
# 1    892.062866   767.939941   945.718262   807.224121    0.846392      2
# 2    614.560669   725.416321   665.787231   763.165344    0.846230      2
# 3    591.839600   780.884766   630.144775   832.889343    0.844663      2
# 4    514.816040   618.693848   545.481812   675.502014    0.838091      2
# 5   1006.868530  1116.523315  1137.951294  1246.852051    0.837527      0
# 6    813.792175   610.245117   862.220093   655.825317    0.832357      2
# 7    657.718262  1117.960327   785.528809  1260.386597    0.829816      0
# 8    630.038696   618.467163   678.853394   659.664978    0.828315      2
# 9    752.983459   629.064575   803.338684   668.233704    0.827893      2
# 10   436.943726  1396.555420   583.247314  1552.484741    0.826107      0
# 11   930.163208   984.941528   962.804626  1038.802490    0.824500      2
# ...

# %%
result.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1213x1600>

# %%
# !python /content/drive/MyDrive/NUT_BOLT/yolov5/detect.py --weights /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/last-fp16.tflite --img 416 --conf 0.25 --source /content/drive/MyDrive/NUT_BOLT/yolov5/dataset/test/t3.jpeg
# Out:
# detect: weights=['/content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/last-fp16.tflite'], source=/content/drive/MyDrive/NUT_BOLT/yolov5/dataset/test/t3.jpeg, data=drive/MyDrive/NUT_BOLT/yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/NUT_BOLT/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# 2023-04-09 17:52:36.812234: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %% [markdown]
#  YAHAN TAK

# %%
# !python /content/drive/MyDrive/NUT_BOLT/yolov5/export.py --weights /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt/weights/last.pt --include tflite --img 416
