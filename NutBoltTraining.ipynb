# %%
# %cd /content/drive/MyDrive/NUT_BOLT
# Out:
# /content/drive/MyDrive/NUT_BOLT

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5
# !pip install -r requirements.txt  # install

# %%
# %rm -rf /content/drive/MyDrive/NUT_BOLT/yolov5/runs/train/nut_bolt2

# %%
# !pip install clearml
# !pip install comet-ml

# %%
# !comet check

# %%
# !export COMET_API_KEY=nutboltVisualization

# %%
import comet_ml
comet_ml.init(project_name='comet-example-yolov5')
# Out:
# Please enter your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Comet API key is valid
# COMET INFO: Comet API key saved in /content/drive/MyDrive/.comet.config

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data obj.yaml --weights yolov5s.pt --name nut_bolt --device 0 --save-period 10

# %%
# !python train.py --resume
